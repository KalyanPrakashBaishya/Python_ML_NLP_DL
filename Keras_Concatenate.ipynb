# %%
# Enabling print for all lines
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Checking the working directory
import os
os.getcwd()
# Out:
# 'C:\\Users\\kalya\\Python'

# %%
# !pip install numpy
# !pip install keras

# %% [markdown]
# As of keras 2, the module `keras.layers.merge` doesn't have a generic public Merge-Layer. Instead we import the subclasses like `keras.layers.Add` or `keras.layers.Concatenate` etc. directly (or their functional interfaces with the same names lowercase: `keras.layers.add`, `keras.layers.concatenate` etc.)
#
# See types of merging layers exist in the [keras docs](https://keras.io/layers/merge/)

# %%
import numpy as np
from keras.models import Model
from keras.layers import Dense, concatenate, Input
from keras.layers import LSTM
from keras.utils import np_utils

# %%
inp1 = Input(shape=(10,20))
inp2 = Input(shape=(10,32))
inp1, inp2

cc1 = concatenate([inp1, inp2],axis=2) # Merge column, same row
cc1
output = Dense(30, activation='relu')(cc1)
output
# Out:
# (<tf.Tensor 'input_1:0' shape=(None, 10, 20) dtype=float32>,
#  <tf.Tensor 'input_2:0' shape=(None, 10, 32) dtype=float32>)
# <tf.Tensor 'concatenate_1/concat:0' shape=(None, 10, 52) dtype=float32>
# <tf.Tensor 'dense_1/Relu:0' shape=(None, 10, 30) dtype=float32>

# %%
model = Model(inputs=[inp1, inp2], outputs=output)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 10, 20)       0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 10, 32)       0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 10, 52)       0           input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10, 30)       1590        concatenate_1[0][0]
# ...
# Total params: 1,590
# Trainable params: 1,590
# Non-trainable params: 0
# ...

# %%
inp1 = Input(shape=(20,10))
inp2 = Input(shape=(32,10))
cc1 = concatenate([inp1, inp2],axis=1) # Merge row, same column
output = Dense(30, activation='relu')(cc1)
model = Model(inputs=[inp1, inp2], outputs=output)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            (None, 20, 10)       0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, 32, 10)       0
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 52, 10)       0           input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 52, 30)       330         concatenate_2[0][0]
# ...
# Total params: 330
# Trainable params: 330
# Non-trainable params: 0
# ...

# %%
inp1 = Input(shape=(10,10))
inp2 = Input(shape=(10,10))
cc1 = concatenate([inp1, inp2],axis=0) # Merge data must same row column
output = Dense(30, activation='relu')(cc1)
model = Model(inputs=[inp1, inp2], outputs=output)
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_5 (InputLayer)            (None, 10, 10)       0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            (None, 10, 10)       0
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 10, 10)       0           input_5[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 10, 30)       330         concatenate_3[0][0]
# ...
# Total params: 330
# Trainable params: 330
# Non-trainable params: 0
# ...
